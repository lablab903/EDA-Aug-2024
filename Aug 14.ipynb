# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the data. Visadataset.csv file has 12 cols

path=r"C:\Users\User\OneDrive\Desktop\Omkar sir\DATA files\Visadataset.csv"

# %%
visa_df=pd.read_csv(r"C:\Users\User\OneDrive\Desktop\Omkar sir\DATA files\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns

num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
# step-1: read the column

# step-2: get the unique labels

# step-3: make a dictionary

# step-4: apply the map

# %%
# visa_df['case_status'].unique()

# %%
# d={'Certified':0,'Denied':1}                                  # dictionary with key: value pairs created

# visa_df['case_status_new']=visa_df['case_status'].map(d)

# %% [markdown]
# **Numerical vs Numerical**
#
# To understand Numerical columns relation we need to plot scatter plots
#
# Scatter plots gives the relation between two numerical columns
#
# Bar chart- pie chart - histogram - scatter plots
#
# scatters plot under matplotlib package
#
# **plt.scatter**

# %%
# Numerical vs Numerical
# using matplotlib pkg, plt() method


x=[1,2,3,4,5]                           # create list 1 with x-coordinates -numerical values

y=[1,2,3,4,5]                           # create list 2 with y-coordinates- numerical values

plt.scatter(x,y)                         # create a scatter graph

#plt.plot(x,y)                            # plotthe graph

plt.show()

# %%
# Numerical vs Numerical
# using matplotlib pkg, plt() method


x=[1,2,3,4,5]                           # create list 1 with x-coordinates

y=[1,2,3,4,5]                           # create list 2 with y-coordinates

plt.scatter(x,y)                         # create a scatter graph of x,y coordiantes

plt.plot(x,y)                            # plot the graph

plt.show()

# %%
# Numerical vs Numerical scatter plot using plt from matplotlib pkg

x=[i for i in range(-10,11)]                         # using list comprehension for x-coordinates from -10 to 10 (numerical)

y=[i*i for i in x]                                    # using list comprehension for y-coordinates from x, -10 to 10 (numerical)

plt.scatter(x,y)                                       # create a scatter graph of x,y coordiantes

plt.plot(x,y)                                         # plot the graph

plt.show()

# %%
pd.DataFrame(zip(x,y))                                 # creating dataframe of the above x,y coordinates from -10 to 10
# Out:
#      0    1
# 0  -10  100
# 1   -9   81
# 2   -8   64
# 3   -7   49
# 4   -6   36
# 5   -5   25
# 6   -4   16
# 7   -3    9
# 8   -2    4
# 9   -1    1
# 10   0    0
# 11   1    1
# 12   2    4
# 13   3    9
# 14   4   16
# 15   5   25
# 16   6   36
# 17   7   49
# 18   8   64
# 19   9   81
# 20  10  100

# %%
# step-1: read one numerical column 
# step-2: read another numerical column 
# apply the scatter plot

# %%
num_columns                                         # numerical cols of Visadataset.csv
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
# creating a scatter graph of 2 numerical cols 'no_of_employees' and 'yr_of_estab'

col1=visa_df['no_of_employees'] 

col2=visa_df['yr_of_estab']

plt.scatter(col1,col2)

plt.plot(col1,col2)                                         # plot the graph

plt.show()

# %%
# student work: no_of_employees vs yr_of estab

x=visa_df.no_of_employees
y=visa_df.yr_of_estab
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
# student work: no_of employees vs prevailing_wage

x=visa_df['no_of_employees']
y=visa_df['prevailing_wage']
plt.scatter(x,y)
plt.plot(x,y)

# %%
# 3 numerical scatter plots

col1=visa_df['no_of_employees']

col2=visa_df['yr_of_estab'] 

col3=visa_df['prevailing_wage'] 

plt.figure(figsize=(14,3)) 


# 1st  numerical scatter plot#############################


plt.subplot(1,3,1).scatter(col1,col2) 

plt.xlabel('no_of_employees') 

plt.ylabel('yr_of_estab')


# 2nd numerical scatter plot########################################


plt.subplot(1,3,2).scatter(col1,col3) 

plt.xlabel('no_of_employees') 

plt.ylabel('prevailing_wage') 


# 3rd numerical scatter plot###################################### 


plt.subplot(1,3,3).scatter(col2,col3)

plt.xlabel('no_of_employees') 

plt.ylabel('prevailing_wage')
# Out:
# Text(0, 0.5, 'prevailing_wage')

# %%
# Mean deviation 

# Absolute mean deviation 

# Variance 

# Covariance

# Correlation coeffiecient

# %% [markdown]
# **Covariance** will tell about the columns have relation or not
# Covariance will explain about relation status
# - postive relation
# - neagtive relation
# - no relation
#
# **Correlation** tells about how much relation between two NUMERIC variables
#
# It denotes with 'r'
#
# r varies from -1 to 1
#
# -1 to 0 indicates negative relation quantity
#
# 0 to 1 indicates postive relation quantity
#
# 0 indicates no relation

# %%
# corr() tells about  relation between two or more NUMERIC variables
# It denotes with 'r'
# r varies from -1 to 1


visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True)
plt.show()

# %% [markdown]
# **Heat map**
# - Heat map is one of the important visualization method , to show the Matrix form of values
# - It is under **seaborn** package
# - In every matrix we have heighest values and lowest values available
# - Heat map will give colour visuliation
# - Also it provides color bar , which color indicates which value

# %%
# heatmap() from seaborn pkg
# Heat map will give colour visuliation
# Also it provides color bar , which color indicates which value

corr_data=visa_df.corr(numeric_only=True)

sns.heatmap(corr_data,annot=True)                 # annotation =true ie values in the map will show

plt.show()

# %%
corr_data=visa_df.corr(numeric_only=True)

sns.heatmap(corr_data)                 

plt.show()

# %%
# cmap=color map here magma color is chosen

corr_data=visa_df.corr(numeric_only=True)

sns.heatmap(corr_data,annot=True,cmap='magma')

plt.show()

# %% [markdown]
#  -   By seeing the Graphs we might not say the relation status
#  -   It is best practice get the percentage of relation using Correlation
#   -  All 3 columns having approximately zero percentage of relation
#  -   Which indicates all the columns having no relation
#  -   No relation means independent each other
#  -   In ML we expect the input columns should be independent each other
#  -   Corr method gives matrix view
#  -   we have 3 columns 3*3 total 9 fields
#   -  If a data has 20 columns then 20*20 total 400 fileds
#  -   Thats why always go with Heat map visulaization
